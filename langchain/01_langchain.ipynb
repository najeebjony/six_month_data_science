# %% [markdown]
# # langchain practice
#
# `pip install langchain`
# `pip install openai`
# `pip install huggingface_hub`
#
#
# ## 1. Introduction
# This is a practice problem for the langchain. The langchain is a series of problems that are designed to help you learn a new programming language. The problems are designed to be simple and to cover a wide range of topics. This problem is the first in the series and is designed to help you get started with the language.

# %%
# import libray

from langchain.llms import OpenAI
import os
os.environ["OPENAI_API_KEY"] = "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"

openai_llm= OpenAI(temperature=0.9) # model_name = 'text-davinci-003'

# input text
input_text = "What is the meaning of life?"
print(openai_llm(input_text))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 11
#       9 # input text
#      10 input_text = "What is the meaning of life?"
# ---> 11 print(openai_llm(input_text))
#
# File c:\Users\HP\miniconda3\envs\ML_env\Lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File c:\Users\HP\miniconda3\envs\ML_env\Lib\site-packages\langchain_core\language_models\llms.py:991, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     984 if not isinstance(prompt, str):
#     985     raise ValueError(
#     986         "Argument `prompt` is expected to be a string. Instead found "
# ...

# %% [markdown]
# # Huggingface

# %%
from langchain import HuggingFaceHub
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"
huggingface_hub = HuggingFaceHub(repo_id="t5-base", model_kwargs={"temperature": 0.9,"max_length": 64})
huggingface_hub("translate English to German: How young are you?")
# Out:
# 'Wie jung bist du?'

# %%
huggingface_hub("can barack Obama have a conversation with George washington?")
# Out:
# 'Kann Barack Obama ein Gespräch mit George Washington führen?'
